# %%
#%pip install cognite-pygen
from cognite.client import CogniteClient

from cognite.pygen import __version__, generate_sdk_notebook

# %%
# Show version, if you have an older you can run
# the installation cell above with:
# %pip install cognite-pygen==0.32.5
__version__
# Out:
# '1.0.2'

# %%
import yaml
import os
from pathlib import Path
from string import Template
from cognite.client import CogniteClient, global_config

file_path = Path("cognite-sdk-config.yaml")

env_sub_template = Template(file_path.read_text())
file_env_parsed = env_sub_template.substitute(dict(os.environ))

cognite_config = yaml.safe_load(file_env_parsed)

global_config.apply_settings(cognite_config["global"])
client = CogniteClient.load(cognite_config["client"])

# %%
space = "radix_space"
data_model_external_id = "RadixEnterpriseDataModel"
data_model_version = "v1"
data_model_id = (space, data_model_external_id, data_model_version)

# %%
pygen = generate_sdk_notebook(data_model_id, client)
# Out:
# Successfully retrieved data model(s) ('radix_space', 'RadixEnterpriseDataModel', 'v1')
# Cleaned temporary directory C:\Users\ANDRE~1.CAR\AppData\Local\Temp\pygen\radix_space_RadixEnterpriseDataModel_v1
# NameCollisionViewPropertyWarning: 17
#      The property 'type' in view Cognite360ImageCollection will have an underscore to avoid name collision.
#      The property 'type' in view Cognite360ImageModel will have an underscore to avoid name collision.
#      The property 'type' in view Cognite3DModel will have an underscore to avoid name collision.
#      The property 'type' in view Cognite3DRevision will have an underscore to avoid name collision.
#      The property 'type' in view CogniteAsset will have an underscore to avoid name collision.
#      The property 'type' in view CogniteCADModel will have an underscore to avoid name collision.
#      The property 'type' in view CogniteCADRevision will have an underscore to avoid name collision.
#      The property 'type' in view CognitePointCloudModel will have an underscore to avoid name collision.
#      The property 'type' in view CognitePointCloudRevision will have an underscore to avoid name collision.
#      The property 'version' in view CogniteSourceSystem will have an underscore to avoid name collision.
#      The property 'type' in view CogniteTimeSeries will have an underscore to avoid name collision.
#      The property 'type' in view MetMast will have an underscore to avoid name collision.
#      The property 'type' in view RadixHorizontalAsset will have an underscore to avoid name collision.
#      The property 'type' in view RadixHorizontalTimeSeries will have an underscore to avoid name collision.
#      The property 'type' in view Substation will have an underscore to avoid name collision.
#      The property 'type' in view WindFarm will have an underscore to avoid name collision.
#      The property 'type' in view WindTurbine will have an underscore to avoid name collision.
# Writing SDK to C:\Users\ANDRE~1.CAR\AppData\Local\Temp\pygen\radix_space_RadixEnterpriseDataModel_v1\radix_enterprise_data_model
# Done!
# C:\Users\ANDRE~1.CAR\AppData\Local\Temp\pygen\radix_space_RadixEnterpriseDataModel_v1 already in sys.path
# Imported radix_enterprise_data_model
# You can now use the generated SDK in the current Python session.
# The data classes are available by importing, for example, `from radix_enterprise_data_model.data_classes import Cognite360ImageWrite`

# %%
pygen.radix_horizontal_asset.list()
# Out:
# RadixHorizontalAssetList([RadixHorizontalAsset(space='radix_space', external_id='react.b_201', data_record=DataRecord(version=14, last_updated_time=datetime.datetime(2025, 3, 28, 16, 17, 1, 385000, tzinfo=datetime.timezone.utc), created_time=datetime.datetime(2025, 3, 28, 13, 24, 44, 213000, tzinfo=datetime.timezone.utc), deleted_time=None), node_type=None, source_id=None, source_context=None, source_created_time=None, source_updated_time=None, source_created_user=None, source_updated_user=None, name='Boiler-201', description='Boiler recovering waste heat', tags=None, aliases=None, path_last_updated_time=datetime.datetime(2025, 3, 28, 16, 17, 1, 385930, tzinfo=TzInfo(UTC)), oee_availability_percent=None, oee_performance_percent=None, oee_quality_percent=None, daily_production_tons=None, daily_target_tons=None, daily_forecast_tons=None),
#                           RadixHorizontalAsset(space='radix_space', external_id='oxi.p_302a', data_record=DataRecord(version=14, last_updated_time=datetime.datetime(2025, 3, 28, 16, 17, 1, 385000, tzinfo=datetime.timezone.utc), created_time=datetime.datetime(2025, 3, 28, 13, 24, 44, 213000, tzinfo=datetime.timezone.utc), deleted_time=None), node_type=None, source_id=None, source_context=None, source_created_time=None, source_updated_time=None, source_created_user=None, source_updated_user=None, name='Pump-302A', description='Nitric acid transfer pump A', tags=None, aliases=None, path_last_updated_time=datetime.datetime(2025, 3, 28, 16, 17, 1, 385930, tzinfo=TzInfo(UTC)), oee_availability_percent=None, oee_performance_percent=None, oee_quality_percent=None, daily_production_tons=None, daily_target_tons=None, daily_forecast_tons=None),
#                           RadixHorizontalAsset(space='radix_space', external_id='oxi.p_303', data_record=DataRecord(version=12, last_updated_time=datetime.datetime(2025, 3, 28, 16, 17, 1, 385000, tzinfo=datetime.timezone.utc), created_time=datetime.datetime(2025, 3, 28, 13, 24, 44, 333000, tzinfo=datetime.timezone.utc), deleted_time=None), node_type=None, source_id=None, source_context=None, source_created_time=None, source_updated_time=None, source_created_user=None, source_updated_user=None, name='Pump-303', description='Cooling pump for absorption tower', tags=None, aliases=None, path_last_updated_time=datetime.datetime(2025, 3, 28, 16, 17, 1, 385930, tzinfo=TzInfo(UTC)), oee_availability_percent=None, oee_performance_percent=None, oee_quality_percent=None, daily_production_tons=None, daily_target_tons=None, daily_forecast_tons=None),
#                           RadixHorizontalAsset(space='radix_space', external_id='react.e_201', data_record=DataRecord(version=13, last_updated_time=datetime.datetime(2025, 3, 28, 16, 17, 1, 385000, tzinfo=datetime.timezone.utc), created_time=datetime.datetime(2025, 3, 28, 13, 24, 44, 333000, tzinfo=datetime.timezone.utc), deleted_time=None), node_type=None, source_id=None, source_context=None, source_created_time=None, source_updated_time=None, source_created_user=None, source_updated_user=None, name='HeatExchanger-201', description='First stage heat exchanger', tags=None, aliases=None, path_last_updated_time=datetime.datetime(2025, 3, 28, 16, 17, 1, 385930, tzinfo=TzInfo(UTC)), oee_availability_percent=None, oee_performance_percent=None, oee_quality_percent=None, daily_production_tons=None, daily_target_tons=None, daily_forecast_tons=None),
#                           RadixHorizontalAsset(space='radix_space', external_id='oxi.c_301', data_record=DataRecord(version=12, last_updated_time=datetime.datetime(2025, 3, 28, 16, 17, 1, 385000, tzinfo=datetime.timezone.utc), created_time=datetime.datetime(2025, 3, 28, 13, 24, 44, 333000, tzinfo=datetime.timezone.utc), deleted_time=None), node_type=None, source_id=None, source_context=None, source_created_time=None, source_updated_time=None, source_created_user=None, source_updated_user=None, name='Column-301', description='Absorption column A for gas treatment', tags=None, aliases=None, path_last_updated_time=datetime.datetime(2025, 3, 28, 16, 17, 1, 385930, tzinfo=TzInfo(UTC)), oee_availability_percent=None, oee_performance_percent=None, oee_quality_percent=None, daily_production_tons=None, daily_target_tons=None, daily_forecast_tons=None),
#                           RadixHorizontalAsset(space='radix_space', external_id='pre.p_101a', data_record=DataRecord(version=11, last_updated_time=datetime.datetime(2025, 3, 28, 16, 17, 1, 385000, tzinfo=datetime.timezone.utc), created_time=datetime.datetime(2025, 3, 28, 13, 24, 44, 333000, tzinfo=datetime.timezone.utc), deleted_time=None), node_type=None, source_id=None, source_context=None, source_created_time=None, source_updated_time=None, source_created_user=None, source_updated_user=None, name='Pump-101A', description='Feed Transfer Pump A for pre-reaction', tags=None, aliases=None, path_last_updated_time=datetime.datetime(2025, 3, 28, 16, 17, 1, 385930, tzinfo=TzInfo(UTC)), oee_availability_percent=None, oee_performance_percent=None, oee_quality_percent=None, daily_production_tons=None, daily_target_tons=None, daily_forecast_tons=None),
#                           RadixHorizontalAsset(space='radix_space', external_id='oxi.comp_301', data_record=DataRecord(version=13, last_updated_time=datetime.datetime(2025, 3, 28, 16, 17, 1, 385000, tzinfo=datetime.timezone.utc), created_time=datetime.datetime(2025, 3, 28, 13, 24, 44, 333000, tzinfo=datetime.timezone.utc), deleted_time=None), node_type=None, source_id=None, source_context=None, source_created_time=None, source_updated_time=None, source_created_user=None, source_updated_user=None, name='Compressor-301', description='Gas compressor A for oxi-absorption', tags=None, aliases=None, path_last_updated_time=datetime.datetime(2025, 3, 28, 16, 17, 1, 385930, tzinfo=TzInfo(UTC)), oee_availability_percent=None, oee_performance_percent=None, oee_quality_percent=None, daily_production_tons=None, daily_target_tons=None, daily_forecast_tons=None),
#                           RadixHorizontalAsset(space='radix_space', external_id='oxi.c_302', data_record=DataRecord(version=13, last_updated_time=datetime.datetime(2025, 3, 28, 16, 17, 1, 385000, tzinfo=datetime.timezone.utc), created_time=datetime.datetime(2025, 3, 28, 13, 24, 44, 333000, tzinfo=datetime.timezone.utc), deleted_time=None), node_type=None, source_id=None, source_context=None, source_created_time=None, source_updated_time=None, source_created_user=None, source_updated_user=None, name='Column-302', description='Absorption column B for gas treatment', tags=None, aliases=None, path_last_updated_time=datetime.datetime(2025, 3, 28, 16, 17, 1, 385930, tzinfo=TzInfo(UTC)), oee_availability_percent=None, oee_performance_percent=None, oee_quality_percent=None, daily_production_tons=None, daily_target_tons=None, daily_forecast_tons=None),
#                           RadixHorizontalAsset(space='radix_space', external_id='plant.acid_nitric', data_record=DataRecord(version=6, last_updated_time=datetime.datetime(2025, 3, 28, 16, 17, 1, 385000, tzinfo=datetime.timezone.utc), created_time=datetime.datetime(2025, 3, 28, 13, 24, 44, 614000, tzinfo=datetime.timezone.utc), deleted_time=None), node_type=None, source_id=None, source_context=None, source_created_time=None, source_updated_time=None, source_created_user=None, source_updated_user=None, name='Acid Nitric Plant', description='Nitric acid production plant', tags=None, aliases=None, path_last_updated_time=datetime.datetime(2025, 3, 28, 16, 17, 1, 385930, tzinfo=TzInfo(UTC)), oee_availability_percent=None, oee_performance_percent=None, oee_quality_percent=None, daily_production_tons=None, daily_target_tons=None, daily_forecast_tons=None),
#                           RadixHorizontalAsset(space='radix_space', external_id='pre.t_101a', data_record=DataRecord(version=8, last_updated_time=datetime.datetime(2025, 3, 28, 16, 17, 1, 385000, tzinfo=datetime.timezone.utc), created_time=datetime.datetime(2025, 3, 28, 13, 24, 44, 614000, tzinfo=datetime.timezone.utc), deleted_time=None), node_type=None, source_id=None, source_context=None, source_created_time=None, source_updated_time=None, source_created_user=None, source_updated_user=None, name='Turbine-101A', description='Steam turbine drive A for pre-reaction', tags=None, aliases=None, path_last_updated_time=datetime.datetime(2025, 3, 28, 16, 17, 1, 385930, tzinfo=TzInfo(UTC)), oee_availability_percent=None, oee_performance_percent=None, oee_quality_percent=None, daily_production_tons=None, daily_target_tons=None, daily_forecast_tons=None),
#                           RadixHorizontalAsset(space='radix_space', external_id='react.e_202', data_record=DataRecord(version=15, last_updated_time=datetime.datetime(2025, 3, 28, 16, 17, 1, 385000, tzinfo=datetime.timezone.utc), created_time=datetime.datetime(2025, 3, 28, 13, 24, 44, 614000, tzinfo=datetime.timezone.utc), deleted_time=None), node_type=None, source_id=None, source_context=None, source_created_time=None, source_updated_time=None, source_created_user=None, source_updated_user=None, name='HeatExchanger-202', description='Second stage heat exchanger', tags=None, aliases=None, path_last_updated_time=datetime.datetime(2025, 3, 28, 16, 17, 1, 385930, tzinfo=TzInfo(UTC)), oee_availability_percent=None, oee_performance_percent=None, oee_quality_percent=None, daily_production_tons=None, daily_target_tons=None, daily_forecast_tons=None),
#                           RadixHorizontalAsset(space='radix_space', external_id='oxi.comp_302', data_record=DataRecord(version=15, last_updated_time=datetime.datetime(2025, 3, 28, 16, 17, 1, 385000, tzinfo=datetime.timezone.utc), created_time=datetime.datetime(2025, 3, 28, 13, 24, 44, 614000, tzinfo=datetime.timezone.utc), deleted_time=None), node_type=None, source_id=None, source_context=None, source_created_time=None, source_updated_time=None, source_created_user=None, source_updated_user=None, name='Compressor-302', description='Gas compressor B for oxi-absorption', tags=None, aliases=None, path_last_updated_time=datetime.datetime(2025, 3, 28, 16, 17, 1, 385930, tzinfo=TzInfo(UTC)), oee_availability_percent=None, oee_performance_percent=None, oee_quality_percent=None, daily_production_tons=None, daily_target_tons=None, daily_forecast_tons=None),
#                           RadixHorizontalAsset(space='radix_space', external_id='oxi.p_302b', data_record=DataRecord(version=15, last_updated_time=datetime.datetime(2025, 3, 28, 16, 17, 1, 385000, tzinfo=datetime.timezone.utc), created_time=datetime.datetime(2025, 3, 28, 13, 24, 44, 614000, tzinfo=datetime.timezone.utc), deleted_time=None), node_type=None, source_id=None, source_context=None, source_created_time=None, source_updated_time=None, source_created_user=None, source_updated_user=None, name='Pump-302B', description='Nitric acid transfer pump B', tags=None, aliases=None, path_last_updated_time=datetime.datetime(2025, 3, 28, 16, 17, 1, 385930, tzinfo=TzInfo(UTC)), oee_availability_percent=None, oee_performance_percent=None, oee_quality_percent=None, daily_production_tons=None, daily_target_tons=None, daily_forecast_tons=None),
#                           RadixHorizontalAsset(space='radix_space', external_id='react.p_201a', data_record=DataRecord(version=15, last_updated_time=datetime.datetime(2025, 3, 28, 16, 17, 1, 385000, tzinfo=datetime.timezone.utc), created_time=datetime.datetime(2025, 3, 28, 13, 24, 44, 614000, tzinfo=datetime.timezone.utc), deleted_time=None), node_type=None, source_id=None, source_context=None, source_created_time=None, source_updated_time=None, source_created_user=None, source_updated_user=None, name='Pump-201A', description='Circulation pump A for reaction unit', tags=None, aliases=None, path_last_updated_time=datetime.datetime(2025, 3, 28, 16, 17, 1, 385930, tzinfo=TzInfo(UTC)), oee_availability_percent=None, oee_performance_percent=None, oee_quality_percent=None, daily_production_tons=None, daily_target_tons=None, daily_forecast_tons=None),
#                           RadixHorizontalAsset(space='radix_space', external_id='pre.mx_101', data_record=DataRecord(version=10, last_updated_time=datetime.datetime(2025, 3, 28, 16, 17, 1, 385000, tzinfo=datetime.timezone.utc), created_time=datetime.datetime(2025, 3, 28, 13, 24, 44, 740000, tzinfo=datetime.timezone.utc), deleted_time=None), node_type=None, source_id=None, source_context=None, source_created_time=None, source_updated_time=None, source_created_user=None, source_updated_user=None, name='Mixer-101', description='Mixer for raw materials in pre-reaction', tags=None, aliases=None, path_last_updated_time=datetime.datetime(2025, 3, 28, 16, 17, 1, 385930, tzinfo=TzInfo(UTC)), oee_availability_percent=None, oee_performance_percent=None, oee_quality_percent=None, daily_production_tons=None, daily_target_tons=None, daily_forecast_tons=None),
#                           RadixHorizontalAsset(space='radix_space', external_id='react.r_201', data_record=DataRecord(version=12, last_updated_time=datetime.datetime(2025, 3, 28, 16, 17, 1, 385000, tzinfo=datetime.timezone.utc), created_time=datetime.datetime(2025, 3, 28, 13, 24, 44, 740000, tzinfo=datetime.timezone.utc), deleted_time=None), node_type=None, source_id=None, source_context=None, source_created_time=None, source_updated_time=None, source_created_user=None, source_updated_user=None, name='Reactor-201', description='Main reactor for nitric acid reaction', tags=None, aliases=None, path_last_updated_time=datetime.datetime(2025, 3, 28, 16, 17, 1, 385930, tzinfo=TzInfo(UTC)), oee_availability_percent=None, oee_performance_percent=None, oee_quality_percent=None, daily_production_tons=None, daily_target_tons=None, daily_forecast_tons=None),
#                           RadixHorizontalAsset(space='radix_space', external_id='react.p_201b', data_record=DataRecord(version=11, last_updated_time=datetime.datetime(2025, 3, 28, 16, 17, 1, 385000, tzinfo=datetime.timezone.utc), created_time=datetime.datetime(2025, 3, 28, 13, 24, 44, 905000, tzinfo=datetime.timezone.utc), deleted_time=None), node_type=None, source_id=None, source_context=None, source_created_time=None, source_updated_time=None, source_created_user=None, source_updated_user=None, name='Pump-201B', description='Circulation pump B for reaction unit', tags=None, aliases=None, path_last_updated_time=datetime.datetime(2025, 3, 28, 16, 17, 1, 385930, tzinfo=TzInfo(UTC)), oee_availability_percent=None, oee_performance_percent=None, oee_quality_percent=None, daily_production_tons=None, daily_target_tons=None, daily_forecast_tons=None),
#                           RadixHorizontalAsset(space='radix_space', external_id='oxi.p_301a', data_record=DataRecord(version=11, last_updated_time=datetime.datetime(2025, 3, 28, 16, 17, 1, 385000, tzinfo=datetime.timezone.utc), created_time=datetime.datetime(2025, 3, 28, 13, 24, 44, 905000, tzinfo=datetime.timezone.utc), deleted_time=None), node_type=None, source_id=None, source_context=None, source_created_time=None, source_updated_time=None, source_created_user=None, source_updated_user=None, name='Pump-301A', description='Absorption circulation pump A', tags=None, aliases=None, path_last_updated_time=datetime.datetime(2025, 3, 28, 16, 17, 1, 385930, tzinfo=TzInfo(UTC)), oee_availability_percent=None, oee_performance_percent=None, oee_quality_percent=None, daily_production_tons=None, daily_target_tons=None, daily_forecast_tons=None),
#                           RadixHorizontalAsset(space='radix_space', external_id='oxi.p_304', data_record=DataRecord(version=14, last_updated_time=datetime.datetime(2025, 3, 28, 16, 17, 1, 385000, tzinfo=datetime.timezone.utc), created_time=datetime.datetime(2025, 3, 28, 13, 24, 45, 420000, tzinfo=datetime.timezone.utc), deleted_time=None), node_type=None, source_id=None, source_context=None, source_created_time=None, source_updated_time=None, source_created_user=None, source_updated_user=None, name='Pump-304', description='Seal water service pump', tags=None, aliases=None, path_last_updated_time=datetime.datetime(2025, 3, 28, 16, 17, 1, 385930, tzinfo=TzInfo(UTC)), oee_availability_percent=None, oee_performance_percent=None, oee_quality_percent=None, daily_production_tons=None, daily_target_tons=None, daily_forecast_tons=None),
#                           RadixHorizontalAsset(space='radix_space', external_id='unit.oxi_absorption', data_record=DataRecord(version=15, last_updated_time=datetime.datetime(2025, 3, 28, 16, 17, 1, 385000, tzinfo=datetime.timezone.utc), created_time=datetime.datetime(2025, 3, 28, 13, 24, 45, 420000, tzinfo=datetime.timezone.utc), deleted_time=None), node_type=None, source_id=None, source_context=None, source_created_time=None, source_updated_time=None, source_created_user=None, source_updated_user=None, name='Oxi-Absorption', description='Oxi-Absorption Unit', tags=None, aliases=None, path_last_updated_time=datetime.datetime(2025, 3, 28, 16, 17, 1, 385930, tzinfo=TzInfo(UTC)), oee_availability_percent=None, oee_performance_percent=None, oee_quality_percent=None, daily_production_tons=None, daily_target_tons=None, daily_forecast_tons=None),
#                           RadixHorizontalAsset(space='radix_space', external_id='unit.react_heat_recovery', data_record=DataRecord(version=15, last_updated_time=datetime.datetime(2025, 3, 28, 16, 17, 1, 385000, tzinfo=datetime.timezone.utc), created_time=datetime.datetime(2025, 3, 28, 13, 24, 45, 420000, tzinfo=datetime.timezone.utc), deleted_time=None), node_type=None, source_id=None, source_context=None, source_created_time=None, source_updated_time=None, source_created_user=None, source_updated_user=None, name='React & Heat Recovery', description='React and Heat Recovery Unit', tags=None, aliases=None, path_last_updated_time=datetime.datetime(2025, 3, 28, 16, 17, 1, 385930, tzinfo=TzInfo(UTC)), oee_availability_percent=None, oee_performance_percent=None, oee_quality_percent=None, daily_production_tons=None, daily_target_tons=None, daily_forecast_tons=None),
#                           RadixHorizontalAsset(space='radix_space', external_id='pre.c_101', data_record=DataRecord(version=8, last_updated_time=datetime.datetime(2025, 3, 28, 16, 17, 1, 385000, tzinfo=datetime.timezone.utc), created_time=datetime.datetime(2025, 3, 28, 13, 24, 45, 420000, tzinfo=datetime.timezone.utc), deleted_time=None), node_type=None, source_id=None, source_context=None, source_created_time=None, source_updated_time=None, source_created_user=None, source_updated_user=None, name='Compressor-101', description='Primary air compressor for pre-reaction', tags=None, aliases=None, path_last_updated_time=datetime.datetime(2025, 3, 28, 16, 17, 1, 385930, tzinfo=TzInfo(UTC)), oee_availability_percent=None, oee_performance_percent=None, oee_quality_percent=None, daily_production_tons=None, daily_target_tons=None, daily_forecast_tons=None),
#                           RadixHorizontalAsset(space='radix_space', external_id='pre.p_101b', data_record=DataRecord(version=8, last_updated_time=datetime.datetime(2025, 3, 28, 16, 17, 1, 385000, tzinfo=datetime.timezone.utc), created_time=datetime.datetime(2025, 3, 28, 13, 24, 45, 420000, tzinfo=datetime.timezone.utc), deleted_time=None), node_type=None, source_id=None, source_context=None, source_created_time=None, source_updated_time=None, source_created_user=None, source_updated_user=None, name='Pump-101B', description='Feed Transfer Pump B for pre-reaction', tags=None, aliases=None, path_last_updated_time=datetime.datetime(2025, 3, 28, 16, 17, 1, 385930, tzinfo=TzInfo(UTC)), oee_availability_percent=None, oee_performance_percent=None, oee_quality_percent=None, daily_production_tons=None, daily_target_tons=None, daily_forecast_tons=None),
#                           RadixHorizontalAsset(space='radix_space', external_id='oxi.p_301b', data_record=DataRecord(version=10, last_updated_time=datetime.datetime(2025, 3, 28, 16, 17, 1, 385000, tzinfo=datetime.timezone.utc), created_time=datetime.datetime(2025, 3, 28, 13, 24, 45, 420000, tzinfo=datetime.timezone.utc), deleted_time=None), node_type=None, source_id=None, source_context=None, source_created_time=None, source_updated_time=None, source_created_user=None, source_updated_user=None, name='Pump-301B', description='Absorption circulation pump B', tags=None, aliases=None, path_last_updated_time=datetime.datetime(2025, 3, 28, 16, 17, 1, 385930, tzinfo=TzInfo(UTC)), oee_availability_percent=None, oee_performance_percent=None, oee_quality_percent=None, daily_production_tons=None, daily_target_tons=None, daily_forecast_tons=None),
#                           RadixHorizontalAsset(space='radix_space', external_id='pre.t_101b', data_record=DataRecord(version=8, last_updated_time=datetime.datetime(2025, 3, 28, 16, 17, 1, 385000, tzinfo=datetime.timezone.utc), created_time=datetime.datetime(2025, 3, 28, 13, 24, 45, 420000, tzinfo=datetime.timezone.utc), deleted_time=None), node_type=None, source_id=None, source_context=None, source_created_time=None, source_updated_time=None, source_created_user=None, source_updated_user=None, name='Turnine-101B', description='Steam turbine drive B for pre-reaction', tags=None, aliases=None, path_last_updated_time=datetime.datetime(2025, 3, 28, 16, 17, 1, 385930, tzinfo=TzInfo(UTC)), oee_availability_percent=None, oee_performance_percent=None, oee_quality_percent=None, daily_production_tons=None, daily_target_tons=None, daily_forecast_tons=None)])
